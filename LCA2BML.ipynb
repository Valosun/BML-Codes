# %% [markdown]
# <a href="https://colab.research.google.com/github/Valosun/PongPython/blob/main/LCA2BML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from scipy.stats import mode

df = pd.read_csv('winequality-red.csv', sep=';')
X = df.drop('quality', axis=1)
y = df['quality']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
n_clusters = len(y.unique())
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# %%
import numpy as np

labels = np.zeros_like(clusters)
for i in range(n_clusters):
    mask = (clusters == i)
    labels[mask] = mode(y[mask])[0]

acc = accuracy_score(y, labels)
print(f'Clustering Accuracy: {acc:.2f}')
# Out:
# Clustering Accuracy: 0.56
